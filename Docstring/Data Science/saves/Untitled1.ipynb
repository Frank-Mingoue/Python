# %%
import pandas as pd
df= pd.read_csv("data.csv")

# %%
df.head(100)
# Out:
#      id        date first_name   last_name                       email  \
# 0     1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1     2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2     3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3     4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4     5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..  ...         ...        ...         ...                         ...
# 95   96  03/09/2021  Winnifred    Hallwood    whallwood2n@virginia.edu
# 96   97  03/20/2021    Devonne    Clowsley      dclowsley2o@ebay.co.uk
# 97   98  03/23/2021    Nikolai     Hallett  nhallett2p@marketwatch.com
# 98   99  03/06/2021    Gerardo      Antley           gantley2q@php.net
# 99  100  03/02/2021        Boy     Jimenez         bjimenez2r@ucla.edu
#
#     gender       ip_address        country price_paid   tax
# ...

# %%
df.isnull()
# Out:
#         id   date  first_name  last_name  email  gender  ip_address  country  \
# 0    False  False       False      False  False   False       False    False
# 1    False  False       False      False  False   False       False    False
# 2    False  False       False      False  False   False       False    False
# 3    False  False       False      False  False   False       False    False
# 4    False  False       False      False  False   False       False    False
# ..     ...    ...         ...        ...    ...     ...         ...      ...
# 995  False  False       False      False  False   False       False    False
# 996  False  False       False      False  False   False       False     True
# 997  False  False       False      False  False   False       False    False
# 998  False  False       False      False  False   False       False    False
# 999  False  False       False      False  False    True       False    False
#
#      price_paid    tax
# ...

# %%
df[df.gender == "Male"]
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 992  993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#     gender       ip_address        country price_paid   tax
# ...

# %%
df[df.gender.isnull()]
# Out:
#        id        date first_name     last_name                        email  \
# 13     14  03/24/2021       Cull        Vassie           cvassied@unblog.fr
# 17     18  03/20/2021       Esta       Boulden      ebouldenh@posterous.com
# 26     27  03/27/2021      Elyse      Glaysher    eglaysherq@mayoclinic.com
# 49     50  03/16/2021   Grantham        Kerins    gkerins1d@paginegialle.it
# 56     57  03/05/2021    Novelia      Najafian        nnajafian1k@cam.ac.uk
# ..    ...         ...        ...           ...                          ...
# 954   955  03/11/2021     Gordie      Rushbury            grushburyqi@51.la
# 977   978  03/14/2021     Bronny       Kemball    bkemballr5@thetimes.co.uk
# 984   985  03/17/2021    Koressa        Abbado  kabbadorc@printfriendly.com
# 989   990  03/16/2021   Horatius  Van Arsdalen     hvanarsdalenrh@prlog.org
# 999  1000  03/23/2021   Rochelle      Pringuer        rpringuerrr@house.gov
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'first_name', 'last_name', 'email', 'gender',
#        'ip_address', 'country', 'price_paid', 'tax'],
#       dtype='object')

# %%
def countNull (dataframe):
    for x in dataframe.columns.values.tolist() :
        dataframe[x]
        #print(dataframe[dataframe.gender == "Male"])

# %%
countNull(df)

# %%
df.email.value_counts()
# Out:
# malders0@shop-pro.jp        1
# aliverockin@spiegel.de      1
# ncotilardia@issuu.com       1
# ljaineib@google.ru          1
# wperrisic@desdev.cn         1
#                            ..
# bcustance9e@disqus.com      1
# mcruddace9f@gizmodo.com     1
# pparslow9g@cpanel.net       1
# rmineghelli9h@spiegel.de    1
# rpringuerrr@house.gov       1
# Name: email, Length: 1000, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# Female    493
# Male      438
# Name: gender, dtype: int64

# %%
df["gender"].value_counts(normalize=True)
# Out:
# Female    0.529538
# Male      0.470462
# Name: gender, dtype: float64

# %%
def countNull (dataframe):
    for x in dataframe.columns.values.tolist() :
        print(x + ":" + str(len(dataframe[dataframe[x].isnull()])))

# %%
len(df[df.gender.isnull()])
# Out:
# 69

# %%
countNull(df)
# Out:
# id:0
# date:0
# first_name:0
# last_name:0
# email:0
# gender:69
# ip_address:0
# country:44
# price_paid:0
# tax:346

# %%
len(df)
# Out:
# 1000

# %%
df.describe()
# Out:
#                 id    tax
# count  1000.000000  654.0
# mean    500.500000   20.0
# std     288.819436    0.0
# min       1.000000   20.0
# 25%     250.750000   20.0
# 50%     500.500000   20.0
# 75%     750.250000   20.0
# max    1000.000000   20.0

# %%
df.price_paid = df.price_paid.apply(lambda x : x.replace("$", ""))
df.price_paid = df.price_paid.astype("float")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\FMINGO~1.TCH\AppData\Local\Temp/ipykernel_22324/1912541952.py in <module>
# ----> 1 df.price_paid = df.price_paid.apply(lambda x : x.replace("$", ""))
#       2 df.price_paid = df.price_paid.astype("float")
#
# C:\Program Files\Python310\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# C:\Program Files\Python310\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# C:\Program Files\Python310\lib\site-packages\pandas\core\apply.py in apply_standard(self)
# ...

# %%
df.price_paid
# Out:
# 0      5.36
# 1      8.32
# 2      3.73
# 3      3.70
# 4      9.24
#        ...
# 995    3.63
# 996    4.59
# 997    7.54
# 998    5.81
# 999    8.01
# Name: price_paid, Length: 1000, dtype: float64

# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df.drop(["first_name", "last_name"], axis=1, inplace=True)

# %%
df
# Out:
#        id        date                       email  gender       ip_address  \
# 0       1  03/28/2021        malders0@shop-pro.jp    Male    160.119.8.119
# 1       2  03/19/2021          hharridge1@gnu.org  Female   210.51.172.132
# 2       3  03/17/2021       ekilminster2@etsy.com    Male    213.8.101.145
# 3       4  03/19/2021            gbrantl3@umn.edu  Female    5.140.237.101
# 4       5  03/24/2021         kbeasant4@jigsy.com    Male  106.252.162.233
# ..    ...         ...                         ...     ...              ...
# 995   996  03/24/2021        derrigorn@elpais.com  Female   193.84.247.144
# 996   997  03/17/2021       arastallro@toplist.cz  Female   188.219.12.109
# 997   998  03/13/2021  bstickelsrp@cloudflare.com    Male     199.80.60.87
# 998   999  03/17/2021      ptesoerq@rakuten.co.jp    Male      0.183.63.11
# 999  1000  03/23/2021       rpringuerrr@house.gov     NaN   170.193.249.83
#
#            country price_paid   tax
# ...

# %%
del(df["id"])

# %%
df
# Out:
#            date                       email  gender       ip_address  \
# 0    03/28/2021        malders0@shop-pro.jp    Male    160.119.8.119
# 1    03/19/2021          hharridge1@gnu.org  Female   210.51.172.132
# 2    03/17/2021       ekilminster2@etsy.com    Male    213.8.101.145
# 3    03/19/2021            gbrantl3@umn.edu  Female    5.140.237.101
# 4    03/24/2021         kbeasant4@jigsy.com    Male  106.252.162.233
# ..          ...                         ...     ...              ...
# 995  03/24/2021        derrigorn@elpais.com  Female   193.84.247.144
# 996  03/17/2021       arastallro@toplist.cz  Female   188.219.12.109
# 997  03/13/2021  bstickelsrp@cloudflare.com    Male     199.80.60.87
# 998  03/17/2021      ptesoerq@rakuten.co.jp    Male      0.183.63.11
# 999  03/23/2021       rpringuerrr@house.gov     NaN   170.193.249.83
#
#            country price_paid   tax
# 0           Canada      $5.36   NaN
# 1           Canada      $8.32   NaN
# ...

# %% [markdown]
# Traiter les valeurs manquantes

# %%
df = pd.read_csv("data.csv")

# %%
df.isnull()
# Out:
#         id   date  first_name  last_name  email  gender  ip_address  country  \
# 0    False  False       False      False  False   False       False    False
# 1    False  False       False      False  False   False       False    False
# 2    False  False       False      False  False   False       False    False
# 3    False  False       False      False  False   False       False    False
# 4    False  False       False      False  False   False       False    False
# ..     ...    ...         ...        ...    ...     ...         ...      ...
# 995  False  False       False      False  False   False       False    False
# 996  False  False       False      False  False   False       False     True
# 997  False  False       False      False  False   False       False    False
# 998  False  False       False      False  False   False       False    False
# 999  False  False       False      False  False    True       False    False
#
#      price_paid    tax
# ...

# %%
df.isnull().sum()
# Out:
# id              0
# date            0
# first_name      0
# last_name       0
# email           0
# gender         69
# ip_address      0
# country        44
# price_paid      0
# tax           346
# dtype: int64

# %%
df[df.tax.isnull()]
# Out:
#       id        date first_name   last_name                   email  gender  \
# 0      1  03/28/2021    Marylin      Alders    malders0@shop-pro.jp    Male
# 1      2  03/19/2021      Hinda    Harridge      hharridge1@gnu.org  Female
# 5      6  03/25/2021      Titos  Braybrooke    tbraybrooke5@umn.edu  Female
# 6      7  03/14/2021        Ava     Kencott      akencott6@phoca.cz  Female
# 9     10  03/23/2021  Guglielma      Gookes   ggookes9@amazon.co.uk    Male
# ..   ...         ...        ...         ...                     ...     ...
# 985  986  03/29/2021     Yvonne  Longworthy   ylongworthyrd@163.com  Female
# 992  993  03/04/2021    Maurene  Guilloneau  mguilloneaurk@about.me    Male
# 993  994  03/22/2021      Ossie      Snelle        osnellerl@nhs.uk    Male
# 995  996  03/24/2021       Duff      Errigo    derrigorn@elpais.com  Female
# 998  999  03/17/2021    Paquito       Tesoe  ptesoerq@rakuten.co.jp    Male
#
#          ip_address        country price_paid  tax
# ...

# %%
df.isnull().any(axis="columns")
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
df[df.isnull().any(axis="columns")]
# Out:
#        id        date first_name   last_name                   email  gender  \
# 0       1  03/28/2021    Marylin      Alders    malders0@shop-pro.jp    Male
# 1       2  03/19/2021      Hinda    Harridge      hharridge1@gnu.org  Female
# 5       6  03/25/2021      Titos  Braybrooke    tbraybrooke5@umn.edu  Female
# 6       7  03/14/2021        Ava     Kencott      akencott6@phoca.cz  Female
# 9      10  03/23/2021  Guglielma      Gookes   ggookes9@amazon.co.uk    Male
# ..    ...         ...        ...         ...                     ...     ...
# 993   994  03/22/2021      Ossie      Snelle        osnellerl@nhs.uk    Male
# 995   996  03/24/2021       Duff      Errigo    derrigorn@elpais.com  Female
# 996   997  03/17/2021        Ame     Rastall   arastallro@toplist.cz  Female
# 998   999  03/17/2021    Paquito       Tesoe  ptesoerq@rakuten.co.jp    Male
# 999  1000  03/23/2021   Rochelle    Pringuer   rpringuerrr@house.gov     NaN
#
# ...

# %%
df.tax.fillna(0, inplace=True)

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df.dropna(subset=['gender', 'country'], inplace=True)

# %%
df.isnull().sum()
# Out:
# id            0
# date          0
# first_name    0
# last_name     0
# email         0
# gender        0
# ip_address    0
# country       0
# price_paid    0
# tax           0
# dtype: int64

# %%
df
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..   ...         ...        ...         ...                         ...
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df.price_paid = df.price_paid.apply(lambda x : x.replace("$", ""))
df.price_paid = df.price_paid.astype(float)
df
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..   ...         ...        ...         ...                         ...
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
df["produc_price"] = df["price_paid"]  * (1 - df["tax"] / 100)

# %%
df["produc_price"] = df["produc_price"].rename("product_price", inplace=True)
df
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..   ...         ...        ...         ...                         ...
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#      gender       ip_address        country  price_paid   tax  produc_price
# ...

# %%
df.query("country =='Canada'")
# Out:
#       id        date first_name   last_name                      email  \
# 0      1  03/28/2021    Marylin      Alders       malders0@shop-pro.jp
# 1      2  03/19/2021      Hinda    Harridge         hharridge1@gnu.org
# 6      7  03/14/2021        Ava     Kencott         akencott6@phoca.cz
# 8      9  03/09/2021     Waylon    Heersema      wheersema8@tumblr.com
# 10    11  03/11/2021       Lief   Woodcraft  lwoodcrafta@sitemeter.com
# ..   ...         ...        ...         ...                        ...
# 940  941  03/24/2021      Torey        Trye        ttryeq4@harvard.edu
# 964  965  03/16/2021    Marilyn   McKiernan       mmckiernanqs@mapy.cz
# 969  970  03/15/2021       Dody  Jakubovics    djakubovicsqx@ifeng.com
# 971  972  03/09/2021      Devan      Kamena          dkamenaqz@umn.edu
# 978  979  03/18/2021  Bartolemo     Veelers      bveelersr6@smh.com.au
#
#      gender       ip_address country  price_paid   tax  produc_price
# ...

# %%
df.country.unique()
# Out:
# array(['Canada', 'United States', 'Morocco', 'France'], dtype=object)

# %%
country_code = {'France': 'FR', 'Canada': 'CA', 'United States': 'US', 'Morocco': "MO"  }

df["coutry_code"] =  df.country.apply(lambda x : country_code[x])

# %%
df
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..   ...         ...        ...         ...                         ...
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#      gender       ip_address        country  price_paid   tax  produc_price  \
# ...

# %%
df.rename(columns={"produc_price": "product_price", "coutry_code": "country_code"}, inplace=True)

# %%
df
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..   ...         ...        ...         ...                         ...
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#      gender       ip_address        country  price_paid   tax  product_price  \
# ...

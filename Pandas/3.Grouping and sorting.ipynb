# %%
import pandas as pd 

reviews = pd.read_csv('Datasets\winemag\winemag-data-130k-v2.csv', index_col=0)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# 1.
# Who are the most common wine reviewers in the dataset? Create a Series whose index is the taster_twitter_handle category from the dataset, and whose values count how many reviews each person wrote.

# %%
reviewers_count = reviews.groupby('taster_twitter_handle').points.count()
reviewers_count

# %%
reviewers_count = reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()

# %%
reviewers_count = reviews.groupby('taster_twitter_handle').taster_twitter_handle.size()

# %%
reviewers_count

# %% [markdown]
# 2.
# What is the best wine I can buy for a given amount of money? Create a Series whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending (so that 4.0 dollars is at the top and 3300.0 dollars is at the bottom).

# %%
best_rating_per_price = reviews.groupby(["price"]).points.max().sort_index()
best_rating_per_price
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
best_rating_per_price_id = list(reviews.groupby(["price"]).points.idxmax().values)
best_rating_per_price_id 

reviews.loc[ best_rating_per_price_id, ["title","price"]]
# Out:
#                                                     title   price
# 64590                       Bandit NV Merlot (California)     4.0
# 24592   In Situ 2008 Reserva Sauvignon Blanc (Aconcagu...     5.0
# 44054    Ste. Chapelle 2001 Johannisberg Riesling (Idaho)     6.0
# 34629   Herdade dos Machados 2012 Toutalga Red (Alente...     7.0
# 26101   Snoqualmie 2006 Winemaker's Select Riesling (C...     8.0
# ...                                                   ...     ...
# 1558                        Château Margaux 2009  Margaux  1900.0
# 65352                        Château Pétrus 2011  Pomerol  2000.0
# 120391  Blair 2013 Roger Rose Vineyard Chardonnay (Arr...  2013.0
# 15840                        Château Pétrus 2014  Pomerol  2500.0
# 80290                Château les Ormes Sorbet 2013  Médoc  3300.0
#
# [390 rows x 2 columns]

# %% [markdown]
# 3.
# What are the minimum and maximum prices for each variety of wine? Create a DataFrame whose index is the variety category from the dataset and whose values are the min and max values thereof.

# %%
price_extremes = reviews.groupby('variety').price.agg(["min","max"])
price_extremes
# Out:
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# Çalkarası    19.0   19.0
# Žilavka      15.0   15.0
#
# [707 rows x 2 columns]

# %% [markdown]
# 4.
# What are the most expensive wine varieties? Create a variable sorted_varieties containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).

# %%
sorted_varieties = price_extremes.sort_values(["min","max"], ascending=[True,False])
sorted_varieties
# Out:
#                                 min     max
# variety
# Chardonnay                      4.0  2013.0
# Syrah                           4.0   750.0
# Cabernet Sauvignon              4.0   625.0
# Merlot                          4.0   625.0
# Tempranillo                     4.0   600.0
# ...                             ...     ...
# Roscetto                        NaN     NaN
# Sauvignon Blanc-Sauvignon Gris  NaN     NaN
# Tempranillo-Malbec              NaN     NaN
# Vital                           NaN     NaN
# Zelen                           NaN     NaN
#
# [707 rows x 2 columns]

# %% [markdown]
# 5.
# Create a Series whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: you will need the taster_name and points columns.

# %%
reviewer_mean_ratings = reviews.groupby("taster_name").points.mean()

# %% [markdown]
# 6.
# What combination of countries and varieties are most common? Create a Series whose index is a MultiIndexof {country, variety} pairs. For example, a pinot noir produced in the US should map to {"US", "Pinot Noir"}. Sort the values in the Series in descending order based on wine count.

# %%
country_variety_counts = reviews.groupby(["country", "variety"]).size().sort_values(ascending=False)
country_variety_counts
# Out:
# country  variety
# US       Pinot Noir                  9885
#          Cabernet Sauvignon          7315
#          Chardonnay                  6801
# France   Bordeaux-style Red Blend    4725
# Italy    Red Blend                   3624
#                                      ...
# Mexico   Cinsault                       1
#          Grenache                       1
#          Merlot                         1
#          Rosado                         1
# Uruguay  White Blend                    1
# Length: 1612, dtype: int64
